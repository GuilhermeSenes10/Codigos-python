# %%
import pandas as pd

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.0 MB 4.0 MB/s
# ...
#      |████████████████████████████████| 6.3 MB 40.8 MB/s
# ...
#      |████████████████████████████████| 16.7 MB 343 kB/s
# ...

# %%
import geopandas as gpd

# %%
sc = gpd.read_file('/content/mapa_sc/SC_UF_2021.shp')

# %%
sc.plot(figsize=(10,10))

# %% [markdown]
# Bibliotecas para matemática

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoint = np.array([0,0,5,5,0])
ypoint = np.array([0,5,5,0,0])

plt.plot(xpoint,ypoint)
